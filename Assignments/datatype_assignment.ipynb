# %% [markdown]
# 1. Write a program to add two lists index-wise. Create a new list that contains the 0th index item from both the list, then the 1st index item, and so on till the last element. any leftover items will get added at the end of the new list.
#
# 	Given List:
#
# 	list1 = ["M", "na", "i", "Ra"]
# 	list2 = ["y", "me", "s", "hul"]

# %%
list1 = ["M", "na", "i", "Ra"]
list2 = ["y", "me", "s", "hul"]

result= []

for a,b in zip(list1, list2):
  result.append(a+b)

print(result)
# Out:
# ['My', 'name', 'is', 'Rahul']

# %% [markdown]
#  Write a program to add item 7000 after 6000 in the following Python List
#
# 	list1 = [10, 20, [300, 400, [5000, 6000], 500], 30, 40]

# %%
list1 = [10, 20, [300, 400, [5000, 6000], 500], 30, 40]

list1[2][2].append(7000)
print(list1)
# Out:
# [10, 20, [300, 400, [5000, 6000, 7000], 500], 30, 40]

# %% [markdown]
# Suppose you are given a list of candy and another list of same size representing no of items of respective candy.
#
# 	i.e -
#
# 	candy_list = ['Jelly Belly','Kit Kat','Double Bubble','Milky Way','Three Musketeers']
# 	no_of_items = [10,20,34,74,32]
# 	Write a program to show no. of items of each candy type.

# %%
candy_list = ['Jelly Belly','Kit Kat','Double Bubble','Milky Way','Three Musketeers']
no_of_items = [10,20,34,74,32]

result= dict(zip(candy_list, no_of_items))

print(result)
# Out:
# {'Jelly Belly': 10, 'Kit Kat': 20, 'Double Bubble': 34, 'Milky Way': 74, 'Three Musketeers': 32}

# %% [markdown]
# Running Sum on list Write a program to print a list after performing running sum on it.
#
# 	i.e:
#
# 	Input:
#
# 	list1 = [1,2,3,4,5,6]

# %%
list1 = [1,2,3,4,5,6]

for i in range(1, len(list1)):
    list1[i] = list1[i] + list1[i-1]

print(list1)
# Out:
# [1, 3, 6, 10, 15, 21]

# %% [markdown]
#  You are given a list of integers. You are asked to make a list by running through elements of the list by adding all elements greater and itself.
#
# 	i.e. Say given list is [2,4,6,10,1] resultant list will be [22,20,10,23].

# %%
result =[]

for i in range(len(list1)):
    result.append(sum(list1[i:]))

print(result)
# Out:
# [23, 21, 17, 11, 1]

# %% [markdown]
#  Find list of common unique items from two list. and show in increasing order
#
# 	Input
#
# 	num1 = [23,45,67,78,89,34]
# 	num2 = [34,89,55,56,39,67]

# %%
num1 = [23,45,67,78,89,34]
num2 = [34,89,55,56,39,67]

result = sorted(set(num1) & set(num2))

print(result)
# Out:
# [34, 67, 89]

# %% [markdown]
# Sort a list of alphanumeric strings based on product value of numeric character in it. If in any string there is no numeric character take it's product value as 1.
#
# 	Input:
#
# 	['1ac21', '23fg', '456', '098d','1','kls']

# %% [markdown]
# Write a program that can find the max number of each row of a matrix
# 	Example:
#
# 	Input:
#
# 	[[1,2,3],[4,5,6],[7,8,9]]

# %%
matrix = [[1,2,3],[4,5,6],[7,8,9]]

result = []

for row in matrix:
    result.append(max(row))

print(result)
# Out:
# [3, 6, 9]

# %% [markdown]
# Shortlist Students for a Job role Ask user to input students record and store in tuples for each record. Then Ask user to input three things he wants in the candidate- Primary Skill, Higher Education, Year of Graduation.
#
# 	Show every students record in form of tuples if matches all required criteria.
#
# 	It is assumed that there will be only one primry skill.
#
# 	If no such candidate found, print No such candidate
#
# 	Input:
#
# 	Enter No of records- 2
# 	Enter Details of student-1
# 	Enter Student name- Manohar
# 	Enter Higher Education- B.Tech
# 	Enter Primary Skill- Python
# 	Enter Year of Graduation- 2022
# 	Enter Details of student-2
# 	Enter Student name- Ponian
# 	Enter Higher Education- B.Sc.
# 	Enter Primary Skill- C++
# 	Enter Year of Graduation- 2020
#
# 	Enter Job Role Requirement
# 	Enter Skill- Python
# 	Enter Higher Education- B.Tech
# 	Enter Year of Graduation- 2022

# %%
students = []

n = int(input("Enter No of records- "))

for i in range(n):
    print(f"Enter Details of student-{i+1}")

    name = input("Enter Student name- ")
    education = input("Enter Higher Education- ")
    skill = input("Enter Primary Skill- ")
    year = int(input("Enter Year of Graduation- "))

    students.append((name, education, skill, year))


# Job requirements
print("Enter Job Role Requirement")
req_skill = input("Enter Skill- ")
req_education = input("Enter Higher Education- ")
req_year = int(input("Enter Year of Graduation- "))


# Filtering
found = False

for student in students:
    if (student[1] == req_education and
        student[2] == req_skill and
        student[3] == req_year):

        print(student)
        found = True

if not found:
    print("No such candidate")
# Out:
# Enter No of records- 2
# Enter Details of student-1
# Enter Student name- xyz
# Enter Higher Education- killing
# Enter Primary Skill- murder
# Enter Year of Graduation- 1000
# Enter Details of student-2
# Enter Student name- onkar
# Enter Higher Education- 10
# Enter Primary Skill- bakchodi
# Enter Year of Graduation- 1994
# Enter Job Role Requirement
# Enter Skill- killing
# Enter Higher Education- 10
# Enter Year of Graduation- 1994
# No such candidate

# %% [markdown]
# Write a program to find set of common elements in three lists using sets.
#
# 	Input : ar1 = [1, 5, 10, 20, 40, 80]
# 			ar2 = [6, 7, 20, 80, 100]
# 			ar3 = [3, 4, 15, 20, 30, 70, 80, 120]

# %%
ar1 = {1, 5, 10, 20, 40, 80}
ar2 = {6, 7, 20, 80, 100}
ar3 = {3, 4, 15, 20, 30, 70, 80, 120}

result= (ar1 & ar2 & ar3)

print(result)
# Out:
# {80, 20}

# %% [markdown]
#  Write a program to count unique number of vowels using sets in a given string. also count of occurancy of each vowel.Lowercase and upercase vowels will be taken as different.
#
# 	Input:
#
# 	Str1 = "hands-on data science mentorship progrAm with live classes at affordable fee only on CampusX"

# %%
Str1 = "hands-on data science mentorship progrAm with live classes at affordable fee only on CampusX"

vowels = "aeiouAEIOU"
unique_vowels = set()
vowel_count ={}

for ch in Str1:
    if ch in vowels:
        unique_vowels.add(ch)

        if ch in vowel_count:
            vowel_count[ch] += 1
        else:
            vowel_count[ch] = 1

print("Unique vowels:", unique_vowels)
print("Count:", len(unique_vowels))
print("frequency", vowel_count)
# Out:
# Unique vowels: {'o', 'a', 'A', 'i', 'u', 'e'}
# Count: 6
# frequency {'a': 8, 'o': 6, 'i': 4, 'e': 8, 'A': 1, 'u': 1}

# %% [markdown]
# Intersection of two lists. Intersection of two list means we need to take all those elements which are common to both of the initial lists and store them into another list. Only use using list-comprehension.
# 	Example 1:
#
# 	Input:
#
# 	lst1 = {15, 9, 10, 56, 23, 78, 5, 4, 9}
# 	lst2 = {9, 4, 5, 36, 47, 26, 10, 45, 87}

# %%
lst1 = {15, 9, 10, 56, 23, 78, 5, 4, 9}
lst2 = {9, 4, 5, 36, 47, 26, 10, 45, 87}

result= (lst1 & lst2)

print(result)
# Out:
# {9, 10, 4, 5}

# %% [markdown]
# Write a Python program to create a class representing a binary search tree. Include methods for inserting and searching for elements in the binary tree
